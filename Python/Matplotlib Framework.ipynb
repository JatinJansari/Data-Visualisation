# %% [markdown]
# # The MATPLOTLIB Framework
# - Create the figure
# - Plot the Data
#     - Multiple times, if desired
# - Configure axes
# - Add annotations
# - Show/save the figure

# %% [markdown]
# ## Standard code structure
# ```
# import matpotlib.pyplot as plt
# plt.figure()
#
#
# plt.plot(x1_values, y1_values)
# plt.plot(x2_values, y2_values)
# plt.plot(x3_values, y3_values)
#
#
# plt.xticks([])
# plt.yticks([])
#
#
# plt.xlim()
# plt.ylim()
# plt.xlabel('')
# plt.ylabel('')
#
#
# plt.legend()
# plt.grid()
# plt.title()
# plt.savefig('*.png')```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

y1_values = [4.2, 2.5, 3.5, 4.5]
y2_values = [2.5, 4.3, 1.8, 2.8]
y3_values = [2, 2, 3, 5]
x1_values = [2012, 2013, 2014, 2015]
x2_values = [2012, 2013, 2014, 2015]
x3_values = [2012, 2013, 2014, 2015]

plt.figure()
plt.plot(x1_values, y1_values, label = 'Python')
plt.plot(x2_values, y2_values, label= 'Javascript')
plt.plot(x3_values, y3_values, label='R')

plt.xlim(2012, 2015)
plt.ylim(1,5)
plt.xticks(x1_values, ['2012','2013','2014','2015'])
plt.xlabel('Year')
plt.ylabel('Web Searches')

plt.legend(loc='upper center', ncol=3)
plt.grid()

plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# ## matplotlib Styles
# ### ALWAYS USE STYLES!
# - saves time, saves code
#
# ### USE ```plt.style.context()``` instead of ```plt.style.use()```
# ### Create separate styles for colors and figure formatting
# Might need to switch between grayscale and color
# ```
# with plt.style.context(['figure_formatting', 'colorbrewer_colors']);
#
# ```
# to
# ```
# with plot.style.context(['figure_formatting', 'grayscale_colors']);
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
y1_values = [4.2, 2.5, 3.5, 4.5]
y2_values = [2.5, 4.3, 1.8, 2.8]
y3_values = [2, 2, 3, 5]
x1_values = [2012, 2013, 2014, 2015]
x2_values = [2012, 2013, 2014, 2015]
x3_values = [2012, 2013, 2014, 2015]



with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label = 'Python')
    plt.plot(x2_values, y2_values, label= 'Javascript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(1,5)
    plt.xticks(x1_values, ['2012','2013','2014','2015'])
    plt.xlabel('Year')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid()

    plt.savefig('web-searches.png', dpi=150)
